# %% [markdown]
# MongoDB연결

# %%
from pymongo import MongoClient

client = MongoClient('localhost', 27017)

print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'test']

# %% [markdown]
# DB 접근

# %%
db = client['test']

# %% [markdown]
# Collection 접근

# %%
collection = db['air']

# %% [markdown]
# # 데이터 전처리

# %%
import json
from bson import json_util

# Collection 접근 - 'airkorea2020_city' Collection
airkorea2020_city = db.air

# 서울
seoul_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
seoul_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
seoul_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
seoul_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
seoul_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
seoul_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
seoul_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
seoul_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
seoul_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
seoul_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
seoul_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
seoul_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^서울" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 부산
busan_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
busan_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
busan_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
busan_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
busan_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
busan_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
busan_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
busan_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
busan_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
busan_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
busan_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
busan_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^부산" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 대구
daegu_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
daegu_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
daegu_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
daegu_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
daegu_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
daegu_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
daegu_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
daegu_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
daegu_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
daegu_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
daegu_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
daegu_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대구" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 인천
incheon_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
incheon_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
incheon_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
incheon_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
incheon_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
incheon_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
incheon_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
incheon_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
incheon_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
incheon_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
incheon_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
incheon_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^인천" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 광주
gwangju_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
gwangju_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
gwangju_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
gwangju_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
gwangju_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
gwangju_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
gwangju_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
gwangju_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
gwangju_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
gwangju_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
gwangju_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
gwangju_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^광주" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 대전
daejeon_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
daejeon_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
daejeon_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
daejeon_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
daejeon_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
daejeon_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
daejeon_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
daejeon_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
daejeon_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
daejeon_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
daejeon_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
daejeon_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^대전" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 울산
ulsan_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
ulsan_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
ulsan_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
ulsan_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
ulsan_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
ulsan_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
ulsan_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
ulsan_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
ulsan_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
ulsan_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
ulsan_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
ulsan_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^울산" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 세종
sejong_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
sejong_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
sejong_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
sejong_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
sejong_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
sejong_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
sejong_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
sejong_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
sejong_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
sejong_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
sejong_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
sejong_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^세종" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 경기
gyeongi_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
gyeongi_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
gyeongi_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
gyeongi_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
gyeongi_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
gyeongi_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
gyeongi_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
gyeongi_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
gyeongi_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
gyeongi_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
gyeongi_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
gyeongi_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경기" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 강원
gangwon_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
gangwon_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
gangwon_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
gangwon_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
gangwon_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
gangwon_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
gangwon_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
gangwon_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
gangwon_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
gangwon_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
gangwon_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
gangwon_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^강원" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 충북
chungbuk_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
chungbuk_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
chungbuk_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
chungbuk_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
chungbuk_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
chungbuk_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
chungbuk_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
chungbuk_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
chungbuk_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
chungbuk_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
chungbuk_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
chungbuk_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충북" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# 충남
chungnam_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
chungnam_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
chungnam_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
chungnam_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
chungnam_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
chungnam_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
chungnam_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
chungnam_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
chungnam_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
chungnam_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
chungnam_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
chungnam_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^충남" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 전북
jeonbuk_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
jeonbuk_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
jeonbuk_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
jeonbuk_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
jeonbuk_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
jeonbuk_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
jeonbuk_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
jeonbuk_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
jeonbuk_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
jeonbuk_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
jeonbuk_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
jeonbuk_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전북" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# 전남
jeonnam_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
jeonnam_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
jeonnam_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
jeonnam_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
jeonnam_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
jeonnam_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
jeonnam_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
jeonnam_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
jeonnam_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
jeonnam_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
jeonnam_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
jeonnam_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^전남" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 경북
kyungbuk_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
kyungbuk_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
kyungbuk_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
kyungbuk_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
kyungbuk_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
kyungbuk_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
kyungbuk_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
kyungbuk_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
kyungbuk_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
kyungbuk_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
kyungbuk_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
kyungbuk_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경북" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# 경남
kyungnam_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
kyungnam_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
kyungnam_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
kyungnam_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
kyungnam_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
kyungnam_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
kyungnam_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
kyungnam_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
kyungnam_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
kyungnam_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
kyungnam_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
kyungnam_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^경남" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
# 제주
jeju_202001_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202001" } } ] } ) )
jeju_202002_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202002" } } ] } ) )
jeju_202003_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202003" } } ] } ) )
jeju_202004_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202004" } } ] } ) )
jeju_202005_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202005" } } ] } ) )
jeju_202006_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202006" } } ] } ) )
jeju_202007_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202007" } } ] } ) )
jeju_202008_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202008" } } ] } ) )
jeju_202009_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202009" } } ] } ) )
jeju_202010_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202010" } } ] } ) )
jeju_202011_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202011" } } ] } ) )
jeju_202012_list = list(airkorea2020_city.find( { "$and": [ { "지역": { "$regex": "^제주" } }, { "측정일시": { "$regex": "^202012" } } ] } ) )

# %%
import pandas as pd

seoul_202001_str = json.dumps(seoul_202001_list, default=json_util.default)
seoul_202001 = json.loads(seoul_202001_str)
seoul_202001_df = pd.DataFrame(seoul_202001)
seoul_202001_PM10=seoul_202001_df["PM10"].mean()
seoul_202001_PM25=seoul_202001_df["PM25"].mean()

seoul_202002_str = json.dumps(seoul_202002_list, default=json_util.default)
seoul_202002 = json.loads(seoul_202002_str)
seoul_202002_df = pd.DataFrame(seoul_202002)
seoul_202002_PM10=seoul_202002_df["PM10"].mean()
seoul_202002_PM25=seoul_202002_df["PM25"].mean()

seoul_202003_str = json.dumps(seoul_202003_list, default=json_util.default)
seoul_202003 = json.loads(seoul_202003_str)
seoul_202003_df = pd.DataFrame(seoul_202003)
seoul_202003_PM10=seoul_202003_df["PM10"].mean()
seoul_202003_PM25=seoul_202003_df["PM25"].mean()

seoul_202004_str = json.dumps(seoul_202004_list, default=json_util.default)
seoul_202004 = json.loads(seoul_202004_str)
seoul_202004_df = pd.DataFrame(seoul_202004)
seoul_202004_PM10=seoul_202004_df["PM10"].mean()
seoul_202004_PM25=seoul_202004_df["PM25"].mean()

seoul_202005_str = json.dumps(seoul_202005_list, default=json_util.default)
seoul_202005 = json.loads(seoul_202005_str)
seoul_202005_df = pd.DataFrame(seoul_202005)
seoul_202005_PM10=seoul_202005_df["PM10"].mean()
seoul_202005_PM25=seoul_202005_df["PM25"].mean()

seoul_202006_str = json.dumps(seoul_202006_list, default=json_util.default)
seoul_202006 = json.loads(seoul_202006_str)
seoul_202006_df = pd.DataFrame(seoul_202006)
seoul_202006_PM10=seoul_202006_df["PM10"].mean()
seoul_202006_PM25=seoul_202006_df["PM25"].mean()

seoul_202007_str = json.dumps(seoul_202007_list, default=json_util.default)
seoul_202007 = json.loads(seoul_202007_str)
seoul_202007_df = pd.DataFrame(seoul_202007)
seoul_202007_PM10=seoul_202007_df["PM10"].mean()
seoul_202007_PM25=seoul_202007_df["PM25"].mean()

seoul_202008_str = json.dumps(seoul_202008_list, default=json_util.default)
seoul_202008 = json.loads(seoul_202008_str)
seoul_202008_df = pd.DataFrame(seoul_202008)
seoul_202008_PM10=seoul_202008_df["PM10"].mean()
seoul_202008_PM25=seoul_202008_df["PM25"].mean()

seoul_202009_str = json.dumps(seoul_202009_list, default=json_util.default)
seoul_202009 = json.loads(seoul_202009_str)
seoul_202009_df = pd.DataFrame(seoul_202009)
seoul_202009_PM10=seoul_202009_df["PM10"].mean()
seoul_202009_PM25=seoul_202009_df["PM25"].mean()

seoul_202010_str = json.dumps(seoul_202010_list, default=json_util.default)
seoul_202010 = json.loads(seoul_202010_str)
seoul_202010_df = pd.DataFrame(seoul_202010)
seoul_202010_PM10=seoul_202010_df["PM10"].mean()
seoul_202010_PM25=seoul_202010_df["PM25"].mean()

seoul_202011_str = json.dumps(seoul_202011_list, default=json_util.default)
seoul_202011 = json.loads(seoul_202011_str)
seoul_202011_df = pd.DataFrame(seoul_202011)
seoul_202011_PM10=seoul_202011_df["PM10"].mean()
seoul_202011_PM25=seoul_202011_df["PM25"].mean()

seoul_202012_str = json.dumps(seoul_202012_list, default=json_util.default)
seoul_202012 = json.loads(seoul_202012_str)
seoul_202012_df = pd.DataFrame(seoul_202012)
seoul_202012_PM10=seoul_202012_df["PM10"].mean()
seoul_202012_PM25=seoul_202012_df["PM25"].mean()

# %%
busan_202001_str = json.dumps(busan_202001_list, default=json_util.default)
busan_202001 = json.loads(busan_202001_str)
busan_202001_df = pd.DataFrame(busan_202001)
busan_202001_PM10=busan_202001_df["PM10"].mean()
busan_202001_PM25=busan_202001_df["PM25"].mean()

busan_202002_str = json.dumps(busan_202002_list, default=json_util.default)
busan_202002 = json.loads(busan_202002_str)
busan_202002_df = pd.DataFrame(busan_202002)
busan_202002_PM10=busan_202002_df["PM10"].mean()
busan_202002_PM25=busan_202002_df["PM25"].mean()

busan_202003_str = json.dumps(busan_202003_list, default=json_util.default)
busan_202003 = json.loads(busan_202003_str)
busan_202003_df = pd.DataFrame(busan_202003)
busan_202003_PM10=busan_202003_df["PM10"].mean()
busan_202003_PM25=busan_202003_df["PM25"].mean()

busan_202004_str = json.dumps(busan_202004_list, default=json_util.default)
busan_202004 = json.loads(busan_202004_str)
busan_202004_df = pd.DataFrame(busan_202004)
busan_202004_PM10=busan_202004_df["PM10"].mean()
busan_202004_PM25=busan_202004_df["PM25"].mean()

busan_202005_str = json.dumps(busan_202005_list, default=json_util.default)
busan_202005 = json.loads(busan_202005_str)
busan_202005_df = pd.DataFrame(busan_202005)
busan_202005_PM10=busan_202005_df["PM10"].mean()
busan_202005_PM25=busan_202005_df["PM25"].mean()

busan_202006_str = json.dumps(busan_202006_list, default=json_util.default)
busan_202006 = json.loads(busan_202006_str)
busan_202006_df = pd.DataFrame(busan_202006)
busan_202006_PM10=busan_202006_df["PM10"].mean()
busan_202006_PM25=busan_202006_df["PM25"].mean()

busan_202007_str = json.dumps(busan_202007_list, default=json_util.default)
busan_202007 = json.loads(busan_202007_str)
busan_202007_df = pd.DataFrame(busan_202007)
busan_202007_PM10=busan_202007_df["PM10"].mean()
busan_202007_PM25=busan_202007_df["PM25"].mean()

busan_202008_str = json.dumps(busan_202008_list, default=json_util.default)
busan_202008 = json.loads(busan_202008_str)
busan_202008_df = pd.DataFrame(busan_202008)
busan_202008_PM10=busan_202008_df["PM10"].mean()
busan_202008_PM25=busan_202008_df["PM25"].mean()

busan_202009_str = json.dumps(busan_202009_list, default=json_util.default)
busan_202009 = json.loads(busan_202009_str)
busan_202009_df = pd.DataFrame(busan_202009)
busan_202009_PM10=busan_202009_df["PM10"].mean()
busan_202009_PM25=busan_202009_df["PM25"].mean()

busan_202010_str = json.dumps(busan_202010_list, default=json_util.default)
busan_202010 = json.loads(busan_202010_str)
busan_202010_df = pd.DataFrame(busan_202010)
busan_202010_PM10=busan_202010_df["PM10"].mean()
busan_202010_PM25=busan_202010_df["PM25"].mean()

busan_202011_str = json.dumps(busan_202011_list, default=json_util.default)
busan_202011 = json.loads(busan_202011_str)
busan_202011_df = pd.DataFrame(busan_202011)
busan_202011_PM10=busan_202011_df["PM10"].mean()
busan_202011_PM25=busan_202011_df["PM25"].mean()

busan_202012_str = json.dumps(busan_202012_list, default=json_util.default)
busan_202012 = json.loads(busan_202012_str)
busan_202012_df = pd.DataFrame(busan_202012)
busan_202012_PM10=busan_202012_df["PM10"].mean()
busan_202012_PM25=busan_202012_df["PM25"].mean()

# %%
daegu_202001_str = json.dumps(daegu_202001_list, default=json_util.default)
daegu_202001 = json.loads(daegu_202001_str)
daegu_202001_df = pd.DataFrame(daegu_202001)
daegu_202001_PM10=daegu_202001_df["PM10"].mean()
daegu_202001_PM25=daegu_202001_df["PM25"].mean()

daegu_202002_str = json.dumps(daegu_202002_list, default=json_util.default)
daegu_202002 = json.loads(daegu_202002_str)
daegu_202002_df = pd.DataFrame(daegu_202002)
daegu_202002_PM10=daegu_202002_df["PM10"].mean()
daegu_202002_PM25=daegu_202002_df["PM25"].mean()

daegu_202003_str = json.dumps(daegu_202003_list, default=json_util.default)
daegu_202003 = json.loads(daegu_202003_str)
daegu_202003_df = pd.DataFrame(daegu_202003)
daegu_202003_PM10=daegu_202003_df["PM10"].mean()
daegu_202003_PM25=daegu_202003_df["PM25"].mean()

daegu_202004_str = json.dumps(daegu_202004_list, default=json_util.default)
daegu_202004 = json.loads(daegu_202004_str)
daegu_202004_df = pd.DataFrame(daegu_202004)
daegu_202004_PM10=daegu_202004_df["PM10"].mean()
daegu_202004_PM25=daegu_202004_df["PM25"].mean()

daegu_202005_str = json.dumps(daegu_202005_list, default=json_util.default)
daegu_202005 = json.loads(daegu_202005_str)
daegu_202005_df = pd.DataFrame(daegu_202005)
daegu_202005_PM10=daegu_202005_df["PM10"].mean()
daegu_202005_PM25=daegu_202005_df["PM25"].mean()

daegu_202006_str = json.dumps(daegu_202006_list, default=json_util.default)
daegu_202006 = json.loads(daegu_202006_str)
daegu_202006_df = pd.DataFrame(daegu_202006)
daegu_202006_PM10=daegu_202006_df["PM10"].mean()
daegu_202006_PM25=daegu_202006_df["PM25"].mean()

daegu_202007_str = json.dumps(daegu_202007_list, default=json_util.default)
daegu_202007 = json.loads(daegu_202007_str)
daegu_202007_df = pd.DataFrame(daegu_202007)
daegu_202007_PM10=daegu_202007_df["PM10"].mean()
daegu_202007_PM25=daegu_202007_df["PM25"].mean()

daegu_202008_str = json.dumps(daegu_202008_list, default=json_util.default)
daegu_202008 = json.loads(daegu_202008_str)
daegu_202008_df = pd.DataFrame(daegu_202008)
daegu_202008_PM10=daegu_202008_df["PM10"].mean()
daegu_202008_PM25=daegu_202008_df["PM25"].mean()

daegu_202009_str = json.dumps(daegu_202009_list, default=json_util.default)
daegu_202009 = json.loads(daegu_202009_str)
daegu_202009_df = pd.DataFrame(daegu_202009)
daegu_202009_PM10=daegu_202009_df["PM10"].mean()
daegu_202009_PM25=daegu_202009_df["PM25"].mean()

daegu_202010_str = json.dumps(daegu_202010_list, default=json_util.default)
daegu_202010 = json.loads(daegu_202010_str)
daegu_202010_df = pd.DataFrame(daegu_202010)
daegu_202010_PM10=daegu_202010_df["PM10"].mean()
daegu_202010_PM25=daegu_202010_df["PM25"].mean()

daegu_202011_str = json.dumps(daegu_202011_list, default=json_util.default)
daegu_202011 = json.loads(daegu_202011_str)
daegu_202011_df = pd.DataFrame(daegu_202011)
daegu_202011_PM10=daegu_202011_df["PM10"].mean()
daegu_202011_PM25=daegu_202011_df["PM25"].mean()

daegu_202012_str = json.dumps(daegu_202012_list, default=json_util.default)
daegu_202012 = json.loads(daegu_202012_str)
daegu_202012_df = pd.DataFrame(daegu_202012)
daegu_202012_PM10=daegu_202012_df["PM10"].mean()
daegu_202012_PM25=daegu_202012_df["PM25"].mean()

# %%
incheon_202001_str = json.dumps(incheon_202001_list, default=json_util.default)
incheon_202001 = json.loads(incheon_202001_str)
incheon_202001_df = pd.DataFrame(incheon_202001)
incheon_202001_PM10=incheon_202001_df["PM10"].mean()
incheon_202001_PM25=incheon_202001_df["PM25"].mean()

incheon_202002_str = json.dumps(incheon_202002_list, default=json_util.default)
incheon_202002 = json.loads(incheon_202002_str)
incheon_202002_df = pd.DataFrame(incheon_202002)
incheon_202002_PM10=incheon_202002_df["PM10"].mean()
incheon_202002_PM25=incheon_202002_df["PM25"].mean()

incheon_202003_str = json.dumps(incheon_202003_list, default=json_util.default)
incheon_202003 = json.loads(incheon_202003_str)
incheon_202003_df = pd.DataFrame(incheon_202003)
incheon_202003_PM10=incheon_202003_df["PM10"].mean()
incheon_202003_PM25=incheon_202003_df["PM25"].mean()

incheon_202004_str = json.dumps(incheon_202004_list, default=json_util.default)
incheon_202004 = json.loads(incheon_202004_str)
incheon_202004_df = pd.DataFrame(incheon_202004)
incheon_202004_PM10=incheon_202004_df["PM10"].mean()
incheon_202004_PM25=incheon_202004_df["PM25"].mean()

incheon_202005_str = json.dumps(incheon_202005_list, default=json_util.default)
incheon_202005 = json.loads(incheon_202005_str)
incheon_202005_df = pd.DataFrame(incheon_202005)
incheon_202005_PM10=incheon_202005_df["PM10"].mean()
incheon_202005_PM25=incheon_202005_df["PM25"].mean()

incheon_202006_str = json.dumps(incheon_202006_list, default=json_util.default)
incheon_202006 = json.loads(incheon_202006_str)
incheon_202006_df = pd.DataFrame(incheon_202006)
incheon_202006_PM10=incheon_202006_df["PM10"].mean()
incheon_202006_PM25=incheon_202006_df["PM25"].mean()

incheon_202007_str = json.dumps(incheon_202007_list, default=json_util.default)
incheon_202007 = json.loads(incheon_202007_str)
incheon_202007_df = pd.DataFrame(incheon_202007)
incheon_202007_PM10=incheon_202007_df["PM10"].mean()
incheon_202007_PM25=incheon_202007_df["PM25"].mean()

incheon_202008_str = json.dumps(incheon_202008_list, default=json_util.default)
incheon_202008 = json.loads(incheon_202008_str)
incheon_202008_df = pd.DataFrame(incheon_202008)
incheon_202008_PM10=incheon_202008_df["PM10"].mean()
incheon_202008_PM25=incheon_202008_df["PM25"].mean()

incheon_202009_str = json.dumps(incheon_202009_list, default=json_util.default)
incheon_202009 = json.loads(incheon_202009_str)
incheon_202009_df = pd.DataFrame(incheon_202009)
incheon_202009_PM10=incheon_202009_df["PM10"].mean()
incheon_202009_PM25=incheon_202009_df["PM25"].mean()

incheon_202010_str = json.dumps(incheon_202010_list, default=json_util.default)
incheon_202010 = json.loads(incheon_202010_str)
incheon_202010_df = pd.DataFrame(incheon_202010)
incheon_202010_PM10=incheon_202010_df["PM10"].mean()
incheon_202010_PM25=incheon_202010_df["PM25"].mean()

incheon_202011_str = json.dumps(incheon_202011_list, default=json_util.default)
incheon_202011 = json.loads(incheon_202011_str)
incheon_202011_df = pd.DataFrame(incheon_202011)
incheon_202011_PM10=incheon_202011_df["PM10"].mean()
incheon_202011_PM25=incheon_202011_df["PM25"].mean()

incheon_202012_str = json.dumps(incheon_202012_list, default=json_util.default)
incheon_202012 = json.loads(incheon_202012_str)
incheon_202012_df = pd.DataFrame(incheon_202012)
incheon_202012_PM10=incheon_202012_df["PM10"].mean()
incheon_202012_PM25=incheon_202012_df["PM25"].mean()

# %%
gwangju_202001_str = json.dumps(gwangju_202001_list, default=json_util.default)
gwangju_202001 = json.loads(gwangju_202001_str)
gwangju_202001_df = pd.DataFrame(gwangju_202001)
gwangju_202001_PM10=gwangju_202001_df["PM10"].mean()
gwangju_202001_PM25=gwangju_202001_df["PM25"].mean()

gwangju_202002_str = json.dumps(gwangju_202002_list, default=json_util.default)
gwangju_202002 = json.loads(gwangju_202002_str)
gwangju_202002_df = pd.DataFrame(gwangju_202002)
gwangju_202002_PM10=gwangju_202002_df["PM10"].mean()
gwangju_202002_PM25=gwangju_202002_df["PM25"].mean()

gwangju_202003_str = json.dumps(gwangju_202003_list, default=json_util.default)
gwangju_202003 = json.loads(gwangju_202003_str)
gwangju_202003_df = pd.DataFrame(gwangju_202003)
gwangju_202003_PM10=gwangju_202003_df["PM10"].mean()
gwangju_202003_PM25=gwangju_202003_df["PM25"].mean()

gwangju_202004_str = json.dumps(gwangju_202004_list, default=json_util.default)
gwangju_202004 = json.loads(gwangju_202004_str)
gwangju_202004_df = pd.DataFrame(gwangju_202004)
gwangju_202004_PM10=gwangju_202004_df["PM10"].mean()
gwangju_202004_PM25=gwangju_202004_df["PM25"].mean()

gwangju_202005_str = json.dumps(gwangju_202005_list, default=json_util.default)
gwangju_202005 = json.loads(gwangju_202005_str)
gwangju_202005_df = pd.DataFrame(gwangju_202005)
gwangju_202005_PM10=gwangju_202005_df["PM10"].mean()
gwangju_202005_PM25=gwangju_202005_df["PM25"].mean()

gwangju_202006_str = json.dumps(gwangju_202006_list, default=json_util.default)
gwangju_202006 = json.loads(gwangju_202006_str)
gwangju_202006_df = pd.DataFrame(gwangju_202006)
gwangju_202006_PM10=gwangju_202006_df["PM10"].mean()
gwangju_202006_PM25=gwangju_202006_df["PM25"].mean()

gwangju_202007_str = json.dumps(gwangju_202007_list, default=json_util.default)
gwangju_202007 = json.loads(gwangju_202007_str)
gwangju_202007_df = pd.DataFrame(gwangju_202007)
gwangju_202007_PM10=gwangju_202007_df["PM10"].mean()
gwangju_202007_PM25=gwangju_202007_df["PM25"].mean()

gwangju_202008_str = json.dumps(gwangju_202008_list, default=json_util.default)
gwangju_202008 = json.loads(gwangju_202008_str)
gwangju_202008_df = pd.DataFrame(gwangju_202008)
gwangju_202008_PM10=gwangju_202008_df["PM10"].mean()
gwangju_202008_PM25=gwangju_202008_df["PM25"].mean()

gwangju_202009_str = json.dumps(gwangju_202009_list, default=json_util.default)
gwangju_202009 = json.loads(gwangju_202009_str)
gwangju_202009_df = pd.DataFrame(gwangju_202009)
gwangju_202009_PM10=gwangju_202009_df["PM10"].mean()
gwangju_202009_PM25=gwangju_202009_df["PM25"].mean()

gwangju_202010_str = json.dumps(gwangju_202010_list, default=json_util.default)
gwangju_202010 = json.loads(gwangju_202010_str)
gwangju_202010_df = pd.DataFrame(gwangju_202010)
gwangju_202010_PM10=gwangju_202010_df["PM10"].mean()
gwangju_202010_PM25=gwangju_202010_df["PM25"].mean()

gwangju_202011_str = json.dumps(gwangju_202011_list, default=json_util.default)
gwangju_202011 = json.loads(gwangju_202011_str)
gwangju_202011_df = pd.DataFrame(gwangju_202011)
gwangju_202011_PM10=gwangju_202011_df["PM10"].mean()
gwangju_202011_PM25=gwangju_202011_df["PM25"].mean()

gwangju_202012_str = json.dumps(gwangju_202012_list, default=json_util.default)
gwangju_202012 = json.loads(gwangju_202012_str)
gwangju_202012_df = pd.DataFrame(gwangju_202012)
gwangju_202012_PM10=gwangju_202012_df["PM10"].mean()
gwangju_202012_PM25=gwangju_202012_df["PM25"].mean()

# %%
daejeon_202001_str = json.dumps(daejeon_202001_list, default=json_util.default)
daejeon_202001 = json.loads(daejeon_202001_str)
daejeon_202001_df = pd.DataFrame(daejeon_202001)
daejeon_202001_PM10=daejeon_202001_df["PM10"].mean()
daejeon_202001_PM25=daejeon_202001_df["PM25"].mean()

daejeon_202002_str = json.dumps(daejeon_202002_list, default=json_util.default)
daejeon_202002 = json.loads(daejeon_202002_str)
daejeon_202002_df = pd.DataFrame(daejeon_202002)
daejeon_202002_PM10=daejeon_202002_df["PM10"].mean()
daejeon_202002_PM25=daejeon_202002_df["PM25"].mean()

daejeon_202003_str = json.dumps(daejeon_202003_list, default=json_util.default)
daejeon_202003 = json.loads(daejeon_202003_str)
daejeon_202003_df = pd.DataFrame(daejeon_202003)
daejeon_202003_PM10=daejeon_202003_df["PM10"].mean()
daejeon_202003_PM25=daejeon_202003_df["PM25"].mean()

daejeon_202004_str = json.dumps(daejeon_202004_list, default=json_util.default)
daejeon_202004 = json.loads(daejeon_202004_str)
daejeon_202004_df = pd.DataFrame(daejeon_202004)
daejeon_202004_PM10=daejeon_202004_df["PM10"].mean()
daejeon_202004_PM25=daejeon_202004_df["PM25"].mean()

daejeon_202005_str = json.dumps(daejeon_202005_list, default=json_util.default)
daejeon_202005 = json.loads(daejeon_202005_str)
daejeon_202005_df = pd.DataFrame(daejeon_202005)
daejeon_202005_PM10=daejeon_202005_df["PM10"].mean()
daejeon_202005_PM25=daejeon_202005_df["PM25"].mean()

daejeon_202006_str = json.dumps(daejeon_202006_list, default=json_util.default)
daejeon_202006 = json.loads(daejeon_202006_str)
daejeon_202006_df = pd.DataFrame(daejeon_202006)
daejeon_202006_PM10=daejeon_202006_df["PM10"].mean()
daejeon_202006_PM25=daejeon_202006_df["PM25"].mean()

daejeon_202007_str = json.dumps(daejeon_202007_list, default=json_util.default)
daejeon_202007 = json.loads(daejeon_202007_str)
daejeon_202007_df = pd.DataFrame(daejeon_202007)
daejeon_202007_PM10=daejeon_202007_df["PM10"].mean()
daejeon_202007_PM25=daejeon_202007_df["PM25"].mean()

daejeon_202008_str = json.dumps(daejeon_202008_list, default=json_util.default)
daejeon_202008 = json.loads(daejeon_202008_str)
daejeon_202008_df = pd.DataFrame(daejeon_202008)
daejeon_202008_PM10=daejeon_202008_df["PM10"].mean()
daejeon_202008_PM25=daejeon_202008_df["PM25"].mean()

daejeon_202009_str = json.dumps(daejeon_202009_list, default=json_util.default)
daejeon_202009 = json.loads(daejeon_202009_str)
daejeon_202009_df = pd.DataFrame(daejeon_202009)
daejeon_202009_PM10=daejeon_202009_df["PM10"].mean()
daejeon_202009_PM25=daejeon_202009_df["PM25"].mean()

daejeon_202010_str = json.dumps(daejeon_202010_list, default=json_util.default)
daejeon_202010 = json.loads(daejeon_202010_str)
daejeon_202010_df = pd.DataFrame(daejeon_202010)
daejeon_202010_PM10=daejeon_202010_df["PM10"].mean()
daejeon_202010_PM25=daejeon_202010_df["PM25"].mean()

daejeon_202011_str = json.dumps(daejeon_202011_list, default=json_util.default)
daejeon_202011 = json.loads(daejeon_202011_str)
daejeon_202011_df = pd.DataFrame(daejeon_202011)
daejeon_202011_PM10=daejeon_202011_df["PM10"].mean()
daejeon_202011_PM25=daejeon_202011_df["PM25"].mean()

daejeon_202012_str = json.dumps(daejeon_202012_list, default=json_util.default)
daejeon_202012 = json.loads(daejeon_202012_str)
daejeon_202012_df = pd.DataFrame(daejeon_202012)
daejeon_202012_PM10=daejeon_202012_df["PM10"].mean()
daejeon_202012_PM25=daejeon_202012_df["PM25"].mean()

# %%
ulsan_202001_str = json.dumps(ulsan_202001_list, default=json_util.default)
ulsan_202001 = json.loads(ulsan_202001_str)
ulsan_202001_df = pd.DataFrame(ulsan_202001)
ulsan_202001_PM10=ulsan_202001_df["PM10"].mean()
ulsan_202001_PM25=ulsan_202001_df["PM25"].mean()

ulsan_202002_str = json.dumps(ulsan_202002_list, default=json_util.default)
ulsan_202002 = json.loads(ulsan_202002_str)
ulsan_202002_df = pd.DataFrame(ulsan_202002)
ulsan_202002_PM10=ulsan_202002_df["PM10"].mean()
ulsan_202002_PM25=ulsan_202002_df["PM25"].mean()

ulsan_202003_str = json.dumps(ulsan_202003_list, default=json_util.default)
ulsan_202003 = json.loads(ulsan_202003_str)
ulsan_202003_df = pd.DataFrame(ulsan_202003)
ulsan_202003_PM10=ulsan_202003_df["PM10"].mean()
ulsan_202003_PM25=ulsan_202003_df["PM25"].mean()

ulsan_202004_str = json.dumps(ulsan_202004_list, default=json_util.default)
ulsan_202004 = json.loads(ulsan_202004_str)
ulsan_202004_df = pd.DataFrame(ulsan_202004)
ulsan_202004_PM10=ulsan_202004_df["PM10"].mean()
ulsan_202004_PM25=ulsan_202004_df["PM25"].mean()

ulsan_202005_str = json.dumps(ulsan_202005_list, default=json_util.default)
ulsan_202005 = json.loads(ulsan_202005_str)
ulsan_202005_df = pd.DataFrame(ulsan_202005)
ulsan_202005_PM10=ulsan_202005_df["PM10"].mean()
ulsan_202005_PM25=ulsan_202005_df["PM25"].mean()

ulsan_202006_str = json.dumps(ulsan_202006_list, default=json_util.default)
ulsan_202006 = json.loads(ulsan_202006_str)
ulsan_202006_df = pd.DataFrame(ulsan_202006)
ulsan_202006_PM10=ulsan_202006_df["PM10"].mean()
ulsan_202006_PM25=ulsan_202006_df["PM25"].mean()

ulsan_202007_str = json.dumps(ulsan_202007_list, default=json_util.default)
ulsan_202007 = json.loads(ulsan_202007_str)
ulsan_202007_df = pd.DataFrame(ulsan_202007)
ulsan_202007_PM10=ulsan_202007_df["PM10"].mean()
ulsan_202007_PM25=ulsan_202007_df["PM25"].mean()

ulsan_202008_str = json.dumps(ulsan_202008_list, default=json_util.default)
ulsan_202008 = json.loads(ulsan_202008_str)
ulsan_202008_df = pd.DataFrame(ulsan_202008)
ulsan_202008_PM10=ulsan_202008_df["PM10"].mean()
ulsan_202008_PM25=ulsan_202008_df["PM25"].mean()

ulsan_202009_str = json.dumps(ulsan_202009_list, default=json_util.default)
ulsan_202009 = json.loads(ulsan_202009_str)
ulsan_202009_df = pd.DataFrame(ulsan_202009)
ulsan_202009_PM10=ulsan_202009_df["PM10"].mean()
ulsan_202009_PM25=ulsan_202009_df["PM25"].mean()

ulsan_202010_str = json.dumps(ulsan_202010_list, default=json_util.default)
ulsan_202010 = json.loads(ulsan_202010_str)
ulsan_202010_df = pd.DataFrame(ulsan_202010)
ulsan_202010_PM10=ulsan_202010_df["PM10"].mean()
ulsan_202010_PM25=ulsan_202010_df["PM25"].mean()

ulsan_202011_str = json.dumps(ulsan_202011_list, default=json_util.default)
ulsan_202011 = json.loads(ulsan_202011_str)
ulsan_202011_df = pd.DataFrame(ulsan_202011)
ulsan_202011_PM10=ulsan_202011_df["PM10"].mean()
ulsan_202011_PM25=ulsan_202011_df["PM25"].mean()

ulsan_202012_str = json.dumps(ulsan_202012_list, default=json_util.default)
ulsan_202012 = json.loads(ulsan_202012_str)
ulsan_202012_df = pd.DataFrame(ulsan_202012)
ulsan_202012_PM10=ulsan_202012_df["PM10"].mean()
ulsan_202012_PM25=ulsan_202012_df["PM25"].mean()

# %%
sejong_202001_str = json.dumps(sejong_202001_list, default=json_util.default)
sejong_202001 = json.loads(sejong_202001_str)
sejong_202001_df = pd.DataFrame(sejong_202001)
sejong_202001_PM10=sejong_202001_df["PM10"].mean()
sejong_202001_PM25=sejong_202001_df["PM25"].mean()

sejong_202002_str = json.dumps(sejong_202002_list, default=json_util.default)
sejong_202002 = json.loads(sejong_202002_str)
sejong_202002_df = pd.DataFrame(sejong_202002)
sejong_202002_PM10=sejong_202002_df["PM10"].mean()
sejong_202002_PM25=sejong_202002_df["PM25"].mean()

sejong_202003_str = json.dumps(sejong_202003_list, default=json_util.default)
sejong_202003 = json.loads(sejong_202003_str)
sejong_202003_df = pd.DataFrame(sejong_202003)
sejong_202003_PM10=sejong_202003_df["PM10"].mean()
sejong_202003_PM25=sejong_202003_df["PM25"].mean()

sejong_202004_str = json.dumps(sejong_202004_list, default=json_util.default)
sejong_202004 = json.loads(sejong_202004_str)
sejong_202004_df = pd.DataFrame(sejong_202004)
sejong_202004_PM10=sejong_202004_df["PM10"].mean()
sejong_202004_PM25=sejong_202004_df["PM25"].mean()

sejong_202005_str = json.dumps(sejong_202005_list, default=json_util.default)
sejong_202005 = json.loads(sejong_202005_str)
sejong_202005_df = pd.DataFrame(sejong_202005)
sejong_202005_PM10=sejong_202005_df["PM10"].mean()
sejong_202005_PM25=sejong_202005_df["PM25"].mean()

sejong_202006_str = json.dumps(sejong_202006_list, default=json_util.default)
sejong_202006 = json.loads(sejong_202006_str)
sejong_202006_df = pd.DataFrame(sejong_202006)
sejong_202006_PM10=sejong_202006_df["PM10"].mean()
sejong_202006_PM25=sejong_202006_df["PM25"].mean()

sejong_202007_str = json.dumps(sejong_202007_list, default=json_util.default)
sejong_202007 = json.loads(sejong_202007_str)
sejong_202007_df = pd.DataFrame(sejong_202007)
sejong_202007_PM10=sejong_202007_df["PM10"].mean()
sejong_202007_PM25=sejong_202007_df["PM25"].mean()

sejong_202008_str = json.dumps(sejong_202008_list, default=json_util.default)
sejong_202008 = json.loads(sejong_202008_str)
sejong_202008_df = pd.DataFrame(sejong_202008)
sejong_202008_PM10=sejong_202008_df["PM10"].mean()
sejong_202008_PM25=sejong_202008_df["PM25"].mean()

sejong_202009_str = json.dumps(sejong_202009_list, default=json_util.default)
sejong_202009 = json.loads(sejong_202009_str)
sejong_202009_df = pd.DataFrame(sejong_202009)
sejong_202009_PM10=sejong_202009_df["PM10"].mean()
sejong_202009_PM25=sejong_202009_df["PM25"].mean()

sejong_202010_str = json.dumps(sejong_202010_list, default=json_util.default)
sejong_202010 = json.loads(sejong_202010_str)
sejong_202010_df = pd.DataFrame(sejong_202010)
sejong_202010_PM10=sejong_202010_df["PM10"].mean()
sejong_202010_PM25=sejong_202010_df["PM25"].mean()

sejong_202011_str = json.dumps(sejong_202011_list, default=json_util.default)
sejong_202011 = json.loads(sejong_202011_str)
sejong_202011_df = pd.DataFrame(sejong_202011)
sejong_202011_PM10=sejong_202011_df["PM10"].mean()
sejong_202011_PM25=sejong_202011_df["PM25"].mean()

sejong_202012_str = json.dumps(sejong_202012_list, default=json_util.default)
sejong_202012 = json.loads(sejong_202012_str)
sejong_202012_df = pd.DataFrame(sejong_202012)
sejong_202012_PM10=sejong_202012_df["PM10"].mean()
sejong_202012_PM25=sejong_202012_df["PM25"].mean()

# %%
gyeongi_202001_str = json.dumps(gyeongi_202001_list, default=json_util.default)
gyeongi_202001 = json.loads(gyeongi_202001_str)
gyeongi_202001_df = pd.DataFrame(gyeongi_202001)
gyeongi_202001_PM10=gyeongi_202001_df["PM10"].mean()
gyeongi_202001_PM25=gyeongi_202001_df["PM25"].mean()

gyeongi_202002_str = json.dumps(gyeongi_202002_list, default=json_util.default)
gyeongi_202002 = json.loads(gyeongi_202002_str)
gyeongi_202002_df = pd.DataFrame(gyeongi_202002)
gyeongi_202002_PM10=gyeongi_202002_df["PM10"].mean()
gyeongi_202002_PM25=gyeongi_202002_df["PM25"].mean()

gyeongi_202003_str = json.dumps(gyeongi_202003_list, default=json_util.default)
gyeongi_202003 = json.loads(gyeongi_202003_str)
gyeongi_202003_df = pd.DataFrame(gyeongi_202003)
gyeongi_202003_PM10=gyeongi_202003_df["PM10"].mean()
gyeongi_202003_PM25=gyeongi_202003_df["PM25"].mean()

gyeongi_202004_str = json.dumps(gyeongi_202004_list, default=json_util.default)
gyeongi_202004 = json.loads(gyeongi_202004_str)
gyeongi_202004_df = pd.DataFrame(gyeongi_202004)
gyeongi_202004_PM10=gyeongi_202004_df["PM10"].mean()
gyeongi_202004_PM25=gyeongi_202004_df["PM25"].mean()

gyeongi_202005_str = json.dumps(gyeongi_202005_list, default=json_util.default)
gyeongi_202005 = json.loads(gyeongi_202005_str)
gyeongi_202005_df = pd.DataFrame(gyeongi_202005)
gyeongi_202005_PM10=gyeongi_202005_df["PM10"].mean()
gyeongi_202005_PM25=gyeongi_202005_df["PM25"].mean()

gyeongi_202006_str = json.dumps(gyeongi_202006_list, default=json_util.default)
gyeongi_202006 = json.loads(gyeongi_202006_str)
gyeongi_202006_df = pd.DataFrame(gyeongi_202006)
gyeongi_202006_PM10=gyeongi_202006_df["PM10"].mean()
gyeongi_202006_PM25=gyeongi_202006_df["PM25"].mean()

gyeongi_202007_str = json.dumps(gyeongi_202007_list, default=json_util.default)
gyeongi_202007 = json.loads(gyeongi_202007_str)
gyeongi_202007_df = pd.DataFrame(gyeongi_202007)
gyeongi_202007_PM10=gyeongi_202007_df["PM10"].mean()
gyeongi_202007_PM25=gyeongi_202007_df["PM25"].mean()

gyeongi_202008_str = json.dumps(gyeongi_202008_list, default=json_util.default)
gyeongi_202008 = json.loads(gyeongi_202008_str)
gyeongi_202008_df = pd.DataFrame(gyeongi_202008)
gyeongi_202008_PM10=gyeongi_202008_df["PM10"].mean()
gyeongi_202008_PM25=gyeongi_202008_df["PM25"].mean()

gyeongi_202009_str = json.dumps(gyeongi_202009_list, default=json_util.default)
gyeongi_202009 = json.loads(gyeongi_202009_str)
gyeongi_202009_df = pd.DataFrame(gyeongi_202009)
gyeongi_202009_PM10=gyeongi_202009_df["PM10"].mean()
gyeongi_202009_PM25=gyeongi_202009_df["PM25"].mean()

gyeongi_202010_str = json.dumps(gyeongi_202010_list, default=json_util.default)
gyeongi_202010 = json.loads(gyeongi_202010_str)
gyeongi_202010_df = pd.DataFrame(gyeongi_202010)
gyeongi_202010_PM10=gyeongi_202010_df["PM10"].mean()
gyeongi_202010_PM25=gyeongi_202010_df["PM25"].mean()

gyeongi_202011_str = json.dumps(gyeongi_202011_list, default=json_util.default)
gyeongi_202011 = json.loads(gyeongi_202011_str)
gyeongi_202011_df = pd.DataFrame(gyeongi_202011)
gyeongi_202011_PM10=gyeongi_202011_df["PM10"].mean()
gyeongi_202011_PM25=gyeongi_202011_df["PM25"].mean()

gyeongi_202012_str = json.dumps(gyeongi_202012_list, default=json_util.default)
gyeongi_202012 = json.loads(gyeongi_202012_str)
gyeongi_202012_df = pd.DataFrame(gyeongi_202012)
gyeongi_202012_PM10=gyeongi_202012_df["PM10"].mean()
gyeongi_202012_PM25=gyeongi_202012_df["PM25"].mean()

# %%
gangwon_202001_str = json.dumps(gangwon_202001_list, default=json_util.default)
gangwon_202001 = json.loads(gangwon_202001_str)
gangwon_202001_df = pd.DataFrame(gangwon_202001)
gangwon_202001_PM10=gangwon_202001_df["PM10"].mean()
gangwon_202001_PM25=gangwon_202001_df["PM25"].mean()

gangwon_202002_str = json.dumps(gangwon_202002_list, default=json_util.default)
gangwon_202002 = json.loads(gangwon_202002_str)
gangwon_202002_df = pd.DataFrame(gangwon_202002)
gangwon_202002_PM10=gangwon_202002_df["PM10"].mean()
gangwon_202002_PM25=gangwon_202002_df["PM25"].mean()

gangwon_202003_str = json.dumps(gangwon_202003_list, default=json_util.default)
gangwon_202003 = json.loads(gangwon_202003_str)
gangwon_202003_df = pd.DataFrame(gangwon_202003)
gangwon_202003_PM10=gangwon_202003_df["PM10"].mean()
gangwon_202003_PM25=gangwon_202003_df["PM25"].mean()

gangwon_202004_str = json.dumps(gangwon_202004_list, default=json_util.default)
gangwon_202004 = json.loads(gangwon_202004_str)
gangwon_202004_df = pd.DataFrame(gangwon_202004)
gangwon_202004_PM10=gangwon_202004_df["PM10"].mean()
gangwon_202004_PM25=gangwon_202004_df["PM25"].mean()

gangwon_202005_str = json.dumps(gangwon_202005_list, default=json_util.default)
gangwon_202005 = json.loads(gangwon_202005_str)
gangwon_202005_df = pd.DataFrame(gangwon_202005)
gangwon_202005_PM10=gangwon_202005_df["PM10"].mean()
gangwon_202005_PM25=gangwon_202005_df["PM25"].mean()

gangwon_202006_str = json.dumps(gangwon_202006_list, default=json_util.default)
gangwon_202006 = json.loads(gangwon_202006_str)
gangwon_202006_df = pd.DataFrame(gangwon_202006)
gangwon_202006_PM10=gangwon_202006_df["PM10"].mean()
gangwon_202006_PM25=gangwon_202006_df["PM25"].mean()

gangwon_202007_str = json.dumps(gangwon_202007_list, default=json_util.default)
gangwon_202007 = json.loads(gangwon_202007_str)
gangwon_202007_df = pd.DataFrame(gangwon_202007)
gangwon_202007_PM10=gangwon_202007_df["PM10"].mean()
gangwon_202007_PM25=gangwon_202007_df["PM25"].mean()

gangwon_202008_str = json.dumps(gangwon_202008_list, default=json_util.default)
gangwon_202008 = json.loads(gangwon_202008_str)
gangwon_202008_df = pd.DataFrame(gangwon_202008)
gangwon_202008_PM10=gangwon_202008_df["PM10"].mean()
gangwon_202008_PM25=gangwon_202008_df["PM25"].mean()

gangwon_202009_str = json.dumps(gangwon_202009_list, default=json_util.default)
gangwon_202009 = json.loads(gangwon_202009_str)
gangwon_202009_df = pd.DataFrame(gangwon_202009)
gangwon_202009_PM10=gangwon_202009_df["PM10"].mean()
gangwon_202009_PM25=gangwon_202009_df["PM25"].mean()

gangwon_202010_str = json.dumps(gangwon_202010_list, default=json_util.default)
gangwon_202010 = json.loads(gangwon_202010_str)
gangwon_202010_df = pd.DataFrame(gangwon_202010)
gangwon_202010_PM10=gangwon_202010_df["PM10"].mean()
gangwon_202010_PM25=gangwon_202010_df["PM25"].mean()

gangwon_202011_str = json.dumps(gangwon_202011_list, default=json_util.default)
gangwon_202011 = json.loads(gangwon_202011_str)
gangwon_202011_df = pd.DataFrame(gangwon_202011)
gangwon_202011_PM10=gangwon_202011_df["PM10"].mean()
gangwon_202011_PM25=gangwon_202011_df["PM25"].mean()

gangwon_202012_str = json.dumps(gangwon_202012_list, default=json_util.default)
gangwon_202012 = json.loads(gangwon_202012_str)
gangwon_202012_df = pd.DataFrame(gangwon_202012)
gangwon_202012_PM10=gangwon_202012_df["PM10"].mean()
gangwon_202012_PM25=gangwon_202012_df["PM25"].mean()

# %%
chungbuk_202001_str = json.dumps(chungbuk_202001_list, default=json_util.default)
chungbuk_202001 = json.loads(chungbuk_202001_str)
chungbuk_202001_df = pd.DataFrame(chungbuk_202001)
chungbuk_202001_PM10=chungbuk_202001_df["PM10"].mean()
chungbuk_202001_PM25=chungbuk_202001_df["PM25"].mean()

chungbuk_202002_str = json.dumps(chungbuk_202002_list, default=json_util.default)
chungbuk_202002 = json.loads(chungbuk_202002_str)
chungbuk_202002_df = pd.DataFrame(chungbuk_202002)
chungbuk_202002_PM10=chungbuk_202002_df["PM10"].mean()
chungbuk_202002_PM25=chungbuk_202002_df["PM25"].mean()

chungbuk_202003_str = json.dumps(chungbuk_202003_list, default=json_util.default)
chungbuk_202003 = json.loads(chungbuk_202003_str)
chungbuk_202003_df = pd.DataFrame(chungbuk_202003)
chungbuk_202003_PM10=chungbuk_202003_df["PM10"].mean()
chungbuk_202003_PM25=chungbuk_202003_df["PM25"].mean()

chungbuk_202004_str = json.dumps(chungbuk_202004_list, default=json_util.default)
chungbuk_202004 = json.loads(chungbuk_202004_str)
chungbuk_202004_df = pd.DataFrame(chungbuk_202004)
chungbuk_202004_PM10=chungbuk_202004_df["PM10"].mean()
chungbuk_202004_PM25=chungbuk_202004_df["PM25"].mean()

chungbuk_202005_str = json.dumps(chungbuk_202005_list, default=json_util.default)
chungbuk_202005 = json.loads(chungbuk_202005_str)
chungbuk_202005_df = pd.DataFrame(chungbuk_202005)
chungbuk_202005_PM10=chungbuk_202005_df["PM10"].mean()
chungbuk_202005_PM25=chungbuk_202005_df["PM25"].mean()

chungbuk_202006_str = json.dumps(chungbuk_202006_list, default=json_util.default)
chungbuk_202006 = json.loads(chungbuk_202006_str)
chungbuk_202006_df = pd.DataFrame(chungbuk_202006)
chungbuk_202006_PM10=chungbuk_202006_df["PM10"].mean()
chungbuk_202006_PM25=chungbuk_202006_df["PM25"].mean()

chungbuk_202007_str = json.dumps(chungbuk_202007_list, default=json_util.default)
chungbuk_202007 = json.loads(chungbuk_202007_str)
chungbuk_202007_df = pd.DataFrame(chungbuk_202007)
chungbuk_202007_PM10=chungbuk_202007_df["PM10"].mean()
chungbuk_202007_PM25=chungbuk_202007_df["PM25"].mean()

chungbuk_202008_str = json.dumps(chungbuk_202008_list, default=json_util.default)
chungbuk_202008 = json.loads(chungbuk_202008_str)
chungbuk_202008_df = pd.DataFrame(chungbuk_202008)
chungbuk_202008_PM10=chungbuk_202008_df["PM10"].mean()
chungbuk_202008_PM25=chungbuk_202008_df["PM25"].mean()

chungbuk_202009_str = json.dumps(chungbuk_202009_list, default=json_util.default)
chungbuk_202009 = json.loads(chungbuk_202009_str)
chungbuk_202009_df = pd.DataFrame(chungbuk_202009)
chungbuk_202009_PM10=chungbuk_202009_df["PM10"].mean()
chungbuk_202009_PM25=chungbuk_202009_df["PM25"].mean()

chungbuk_202010_str = json.dumps(chungbuk_202010_list, default=json_util.default)
chungbuk_202010 = json.loads(chungbuk_202010_str)
chungbuk_202010_df = pd.DataFrame(chungbuk_202010)
chungbuk_202010_PM10=chungbuk_202010_df["PM10"].mean()
chungbuk_202010_PM25=chungbuk_202010_df["PM25"].mean()

chungbuk_202011_str = json.dumps(chungbuk_202011_list, default=json_util.default)
chungbuk_202011 = json.loads(chungbuk_202011_str)
chungbuk_202011_df = pd.DataFrame(chungbuk_202011)
chungbuk_202011_PM10=chungbuk_202011_df["PM10"].mean()
chungbuk_202011_PM25=chungbuk_202011_df["PM25"].mean()

chungbuk_202012_str = json.dumps(chungbuk_202012_list, default=json_util.default)
chungbuk_202012 = json.loads(chungbuk_202012_str)
chungbuk_202012_df = pd.DataFrame(chungbuk_202012)
chungbuk_202012_PM10=chungbuk_202012_df["PM10"].mean()
chungbuk_202012_PM25=chungbuk_202012_df["PM25"].mean()

# %%
chungnam_202001_str = json.dumps(chungnam_202001_list, default=json_util.default)
chungnam_202001 = json.loads(chungnam_202001_str)
chungnam_202001_df = pd.DataFrame(chungnam_202001)
chungnam_202001_PM10=chungnam_202001_df["PM10"].mean()
chungnam_202001_PM25=chungnam_202001_df["PM25"].mean()

chungnam_202002_str = json.dumps(chungnam_202002_list, default=json_util.default)
chungnam_202002 = json.loads(chungnam_202002_str)
chungnam_202002_df = pd.DataFrame(chungnam_202002)
chungnam_202002_PM10=chungnam_202002_df["PM10"].mean()
chungnam_202002_PM25=chungnam_202002_df["PM25"].mean()

chungnam_202003_str = json.dumps(chungnam_202003_list, default=json_util.default)
chungnam_202003 = json.loads(chungnam_202003_str)
chungnam_202003_df = pd.DataFrame(chungnam_202003)
chungnam_202003_PM10=chungnam_202003_df["PM10"].mean()
chungnam_202003_PM25=chungnam_202003_df["PM25"].mean()

chungnam_202004_str = json.dumps(chungnam_202004_list, default=json_util.default)
chungnam_202004 = json.loads(chungnam_202004_str)
chungnam_202004_df = pd.DataFrame(chungnam_202004)
chungnam_202004_PM10=chungnam_202004_df["PM10"].mean()
chungnam_202004_PM25=chungnam_202004_df["PM25"].mean()

chungnam_202005_str = json.dumps(chungnam_202005_list, default=json_util.default)
chungnam_202005 = json.loads(chungnam_202005_str)
chungnam_202005_df = pd.DataFrame(chungnam_202005)
chungnam_202005_PM10=chungnam_202005_df["PM10"].mean()
chungnam_202005_PM25=chungnam_202005_df["PM25"].mean()

chungnam_202006_str = json.dumps(chungnam_202006_list, default=json_util.default)
chungnam_202006 = json.loads(chungnam_202006_str)
chungnam_202006_df = pd.DataFrame(chungnam_202006)
chungnam_202006_PM10=chungnam_202006_df["PM10"].mean()
chungnam_202006_PM25=chungnam_202006_df["PM25"].mean()

chungnam_202007_str = json.dumps(chungnam_202007_list, default=json_util.default)
chungnam_202007 = json.loads(chungnam_202007_str)
chungnam_202007_df = pd.DataFrame(chungnam_202007)
chungnam_202007_PM10=chungnam_202007_df["PM10"].mean()
chungnam_202007_PM25=chungnam_202007_df["PM25"].mean()

chungnam_202008_str = json.dumps(chungnam_202008_list, default=json_util.default)
chungnam_202008 = json.loads(chungnam_202008_str)
chungnam_202008_df = pd.DataFrame(chungnam_202008)
chungnam_202008_PM10=chungnam_202008_df["PM10"].mean()
chungnam_202008_PM25=chungnam_202008_df["PM25"].mean()

chungnam_202009_str = json.dumps(chungnam_202009_list, default=json_util.default)
chungnam_202009 = json.loads(chungnam_202009_str)
chungnam_202009_df = pd.DataFrame(chungnam_202009)
chungnam_202009_PM10=chungnam_202009_df["PM10"].mean()
chungnam_202009_PM25=chungnam_202009_df["PM25"].mean()

chungnam_202010_str = json.dumps(chungnam_202010_list, default=json_util.default)
chungnam_202010 = json.loads(chungnam_202010_str)
chungnam_202010_df = pd.DataFrame(chungnam_202010)
chungnam_202010_PM10=chungnam_202010_df["PM10"].mean()
chungnam_202010_PM25=chungnam_202010_df["PM25"].mean()

chungnam_202011_str = json.dumps(chungnam_202011_list, default=json_util.default)
chungnam_202011 = json.loads(chungnam_202011_str)
chungnam_202011_df = pd.DataFrame(chungnam_202011)
chungnam_202011_PM10=chungnam_202011_df["PM10"].mean()
chungnam_202011_PM25=chungnam_202011_df["PM25"].mean()

chungnam_202012_str = json.dumps(chungnam_202012_list, default=json_util.default)
chungnam_202012 = json.loads(chungnam_202012_str)
chungnam_202012_df = pd.DataFrame(chungnam_202012)
chungnam_202012_PM10=chungnam_202012_df["PM10"].mean()
chungnam_202012_PM25=chungnam_202012_df["PM25"].mean()

# %%
jeonbuk_202001_str = json.dumps(jeonbuk_202001_list, default=json_util.default)
jeonbuk_202001 = json.loads(jeonbuk_202001_str)
jeonbuk_202001_df = pd.DataFrame(jeonbuk_202001)
jeonbuk_202001_PM10=jeonbuk_202001_df["PM10"].mean()
jeonbuk_202001_PM25=jeonbuk_202001_df["PM25"].mean()

jeonbuk_202002_str = json.dumps(jeonbuk_202002_list, default=json_util.default)
jeonbuk_202002 = json.loads(jeonbuk_202002_str)
jeonbuk_202002_df = pd.DataFrame(jeonbuk_202002)
jeonbuk_202002_PM10=jeonbuk_202002_df["PM10"].mean()
jeonbuk_202002_PM25=jeonbuk_202002_df["PM25"].mean()

jeonbuk_202003_str = json.dumps(jeonbuk_202003_list, default=json_util.default)
jeonbuk_202003 = json.loads(jeonbuk_202003_str)
jeonbuk_202003_df = pd.DataFrame(jeonbuk_202003)
jeonbuk_202003_PM10=jeonbuk_202003_df["PM10"].mean()
jeonbuk_202003_PM25=jeonbuk_202003_df["PM25"].mean()

jeonbuk_202004_str = json.dumps(jeonbuk_202004_list, default=json_util.default)
jeonbuk_202004 = json.loads(jeonbuk_202004_str)
jeonbuk_202004_df = pd.DataFrame(jeonbuk_202004)
jeonbuk_202004_PM10=jeonbuk_202004_df["PM10"].mean()
jeonbuk_202004_PM25=jeonbuk_202004_df["PM25"].mean()

jeonbuk_202005_str = json.dumps(jeonbuk_202005_list, default=json_util.default)
jeonbuk_202005 = json.loads(jeonbuk_202005_str)
jeonbuk_202005_df = pd.DataFrame(jeonbuk_202005)
jeonbuk_202005_PM10=jeonbuk_202005_df["PM10"].mean()
jeonbuk_202005_PM25=jeonbuk_202005_df["PM25"].mean()

jeonbuk_202006_str = json.dumps(jeonbuk_202006_list, default=json_util.default)
jeonbuk_202006 = json.loads(jeonbuk_202006_str)
jeonbuk_202006_df = pd.DataFrame(jeonbuk_202006)
jeonbuk_202006_PM10=jeonbuk_202006_df["PM10"].mean()
jeonbuk_202006_PM25=jeonbuk_202006_df["PM25"].mean()

jeonbuk_202007_str = json.dumps(jeonbuk_202007_list, default=json_util.default)
jeonbuk_202007 = json.loads(jeonbuk_202007_str)
jeonbuk_202007_df = pd.DataFrame(jeonbuk_202007)
jeonbuk_202007_PM10=jeonbuk_202007_df["PM10"].mean()
jeonbuk_202007_PM25=jeonbuk_202007_df["PM25"].mean()

jeonbuk_202008_str = json.dumps(jeonbuk_202008_list, default=json_util.default)
jeonbuk_202008 = json.loads(jeonbuk_202008_str)
jeonbuk_202008_df = pd.DataFrame(jeonbuk_202008)
jeonbuk_202008_PM10=jeonbuk_202008_df["PM10"].mean()
jeonbuk_202008_PM25=jeonbuk_202008_df["PM25"].mean()

jeonbuk_202009_str = json.dumps(jeonbuk_202009_list, default=json_util.default)
jeonbuk_202009 = json.loads(jeonbuk_202009_str)
jeonbuk_202009_df = pd.DataFrame(jeonbuk_202009)
jeonbuk_202009_PM10=jeonbuk_202009_df["PM10"].mean()
jeonbuk_202009_PM25=jeonbuk_202009_df["PM25"].mean()

jeonbuk_202010_str = json.dumps(jeonbuk_202010_list, default=json_util.default)
jeonbuk_202010 = json.loads(jeonbuk_202010_str)
jeonbuk_202010_df = pd.DataFrame(jeonbuk_202010)
jeonbuk_202010_PM10=jeonbuk_202010_df["PM10"].mean()
jeonbuk_202010_PM25=jeonbuk_202010_df["PM25"].mean()

jeonbuk_202011_str = json.dumps(jeonbuk_202011_list, default=json_util.default)
jeonbuk_202011 = json.loads(jeonbuk_202011_str)
jeonbuk_202011_df = pd.DataFrame(jeonbuk_202011)
jeonbuk_202011_PM10=jeonbuk_202011_df["PM10"].mean()
jeonbuk_202011_PM25=jeonbuk_202011_df["PM25"].mean()

jeonbuk_202012_str = json.dumps(jeonbuk_202012_list, default=json_util.default)
jeonbuk_202012 = json.loads(jeonbuk_202012_str)
jeonbuk_202012_df = pd.DataFrame(jeonbuk_202012)
jeonbuk_202012_PM10=jeonbuk_202012_df["PM10"].mean()
jeonbuk_202012_PM25=jeonbuk_202012_df["PM25"].mean()

# %%
jeonnam_202001_str = json.dumps(jeonnam_202001_list, default=json_util.default)
jeonnam_202001 = json.loads(jeonnam_202001_str)
jeonnam_202001_df = pd.DataFrame(jeonnam_202001)
jeonnam_202001_PM10=jeonnam_202001_df["PM10"].mean()
jeonnam_202001_PM25=jeonnam_202001_df["PM25"].mean()

jeonnam_202002_str = json.dumps(jeonnam_202002_list, default=json_util.default)
jeonnam_202002 = json.loads(jeonnam_202002_str)
jeonnam_202002_df = pd.DataFrame(jeonnam_202002)
jeonnam_202002_PM10=jeonnam_202002_df["PM10"].mean()
jeonnam_202002_PM25=jeonnam_202002_df["PM25"].mean()

jeonnam_202003_str = json.dumps(jeonnam_202003_list, default=json_util.default)
jeonnam_202003 = json.loads(jeonnam_202003_str)
jeonnam_202003_df = pd.DataFrame(jeonnam_202003)
jeonnam_202003_PM10=jeonnam_202003_df["PM10"].mean()
jeonnam_202003_PM25=jeonnam_202003_df["PM25"].mean()

jeonnam_202004_str = json.dumps(jeonnam_202004_list, default=json_util.default)
jeonnam_202004 = json.loads(jeonnam_202004_str)
jeonnam_202004_df = pd.DataFrame(jeonnam_202004)
jeonnam_202004_PM10=jeonnam_202004_df["PM10"].mean()
jeonnam_202004_PM25=jeonnam_202004_df["PM25"].mean()

jeonnam_202005_str = json.dumps(jeonnam_202005_list, default=json_util.default)
jeonnam_202005 = json.loads(jeonnam_202005_str)
jeonnam_202005_df = pd.DataFrame(jeonnam_202005)
jeonnam_202005_PM10=jeonnam_202005_df["PM10"].mean()
jeonnam_202005_PM25=jeonnam_202005_df["PM25"].mean()

jeonnam_202006_str = json.dumps(jeonnam_202006_list, default=json_util.default)
jeonnam_202006 = json.loads(jeonnam_202006_str)
jeonnam_202006_df = pd.DataFrame(jeonnam_202006)
jeonnam_202006_PM10=jeonnam_202006_df["PM10"].mean()
jeonnam_202006_PM25=jeonnam_202006_df["PM25"].mean()

jeonnam_202007_str = json.dumps(jeonnam_202007_list, default=json_util.default)
jeonnam_202007 = json.loads(jeonnam_202007_str)
jeonnam_202007_df = pd.DataFrame(jeonnam_202007)
jeonnam_202007_PM10=jeonnam_202007_df["PM10"].mean()
jeonnam_202007_PM25=jeonnam_202007_df["PM25"].mean()

jeonnam_202008_str = json.dumps(jeonnam_202008_list, default=json_util.default)
jeonnam_202008 = json.loads(jeonnam_202008_str)
jeonnam_202008_df = pd.DataFrame(jeonnam_202008)
jeonnam_202008_PM10=jeonnam_202008_df["PM10"].mean()
jeonnam_202008_PM25=jeonnam_202008_df["PM25"].mean()

jeonnam_202009_str = json.dumps(jeonnam_202009_list, default=json_util.default)
jeonnam_202009 = json.loads(jeonnam_202009_str)
jeonnam_202009_df = pd.DataFrame(jeonnam_202009)
jeonnam_202009_PM10=jeonnam_202009_df["PM10"].mean()
jeonnam_202009_PM25=jeonnam_202009_df["PM25"].mean()

jeonnam_202010_str = json.dumps(jeonnam_202010_list, default=json_util.default)
jeonnam_202010 = json.loads(jeonnam_202010_str)
jeonnam_202010_df = pd.DataFrame(jeonnam_202010)
jeonnam_202010_PM10=jeonnam_202010_df["PM10"].mean()
jeonnam_202010_PM25=jeonnam_202010_df["PM25"].mean()

jeonnam_202011_str = json.dumps(jeonnam_202011_list, default=json_util.default)
jeonnam_202011 = json.loads(jeonnam_202011_str)
jeonnam_202011_df = pd.DataFrame(jeonnam_202011)
jeonnam_202011_PM10=jeonnam_202011_df["PM10"].mean()
jeonnam_202011_PM25=jeonnam_202011_df["PM25"].mean()

jeonnam_202012_str = json.dumps(jeonnam_202012_list, default=json_util.default)
jeonnam_202012 = json.loads(jeonnam_202012_str)
jeonnam_202012_df = pd.DataFrame(jeonnam_202012)
jeonnam_202012_PM10=jeonnam_202012_df["PM10"].mean()
jeonnam_202012_PM25=jeonnam_202012_df["PM25"].mean()

# %%
kyungbuk_202001_str = json.dumps(kyungbuk_202001_list, default=json_util.default)
kyungbuk_202001 = json.loads(kyungbuk_202001_str)
kyungbuk_202001_df = pd.DataFrame(kyungbuk_202001)
kyungbuk_202001_PM10=kyungbuk_202001_df["PM10"].mean()
kyungbuk_202001_PM25=kyungbuk_202001_df["PM25"].mean()

kyungbuk_202002_str = json.dumps(kyungbuk_202002_list, default=json_util.default)
kyungbuk_202002 = json.loads(kyungbuk_202002_str)
kyungbuk_202002_df = pd.DataFrame(kyungbuk_202002)
kyungbuk_202002_PM10=kyungbuk_202002_df["PM10"].mean()
kyungbuk_202002_PM25=kyungbuk_202002_df["PM25"].mean()

kyungbuk_202003_str = json.dumps(kyungbuk_202003_list, default=json_util.default)
kyungbuk_202003 = json.loads(kyungbuk_202003_str)
kyungbuk_202003_df = pd.DataFrame(kyungbuk_202003)
kyungbuk_202003_PM10=kyungbuk_202003_df["PM10"].mean()
kyungbuk_202003_PM25=kyungbuk_202003_df["PM25"].mean()

kyungbuk_202004_str = json.dumps(kyungbuk_202004_list, default=json_util.default)
kyungbuk_202004 = json.loads(kyungbuk_202004_str)
kyungbuk_202004_df = pd.DataFrame(kyungbuk_202004)
kyungbuk_202004_PM10=kyungbuk_202004_df["PM10"].mean()
kyungbuk_202004_PM25=kyungbuk_202004_df["PM25"].mean()

kyungbuk_202005_str = json.dumps(kyungbuk_202005_list, default=json_util.default)
kyungbuk_202005 = json.loads(kyungbuk_202005_str)
kyungbuk_202005_df = pd.DataFrame(kyungbuk_202005)
kyungbuk_202005_PM10=kyungbuk_202005_df["PM10"].mean()
kyungbuk_202005_PM25=kyungbuk_202005_df["PM25"].mean()

kyungbuk_202006_str = json.dumps(kyungbuk_202006_list, default=json_util.default)
kyungbuk_202006 = json.loads(kyungbuk_202006_str)
kyungbuk_202006_df = pd.DataFrame(kyungbuk_202006)
kyungbuk_202006_PM10=kyungbuk_202006_df["PM10"].mean()
kyungbuk_202006_PM25=kyungbuk_202006_df["PM25"].mean()

kyungbuk_202007_str = json.dumps(kyungbuk_202007_list, default=json_util.default)
kyungbuk_202007 = json.loads(kyungbuk_202007_str)
kyungbuk_202007_df = pd.DataFrame(kyungbuk_202007)
kyungbuk_202007_PM10=kyungbuk_202007_df["PM10"].mean()
kyungbuk_202007_PM25=kyungbuk_202007_df["PM25"].mean()

kyungbuk_202008_str = json.dumps(kyungbuk_202008_list, default=json_util.default)
kyungbuk_202008 = json.loads(kyungbuk_202008_str)
kyungbuk_202008_df = pd.DataFrame(kyungbuk_202008)
kyungbuk_202008_PM10=kyungbuk_202008_df["PM10"].mean()
kyungbuk_202008_PM25=kyungbuk_202008_df["PM25"].mean()

kyungbuk_202009_str = json.dumps(kyungbuk_202009_list, default=json_util.default)
kyungbuk_202009 = json.loads(kyungbuk_202009_str)
kyungbuk_202009_df = pd.DataFrame(kyungbuk_202009)
kyungbuk_202009_PM10=kyungbuk_202009_df["PM10"].mean()
kyungbuk_202009_PM25=kyungbuk_202009_df["PM25"].mean()

kyungbuk_202010_str = json.dumps(kyungbuk_202010_list, default=json_util.default)
kyungbuk_202010 = json.loads(kyungbuk_202010_str)
kyungbuk_202010_df = pd.DataFrame(kyungbuk_202010)
kyungbuk_202010_PM10=kyungbuk_202010_df["PM10"].mean()
kyungbuk_202010_PM25=kyungbuk_202010_df["PM25"].mean()

kyungbuk_202011_str = json.dumps(kyungbuk_202011_list, default=json_util.default)
kyungbuk_202011 = json.loads(kyungbuk_202011_str)
kyungbuk_202011_df = pd.DataFrame(kyungbuk_202011)
kyungbuk_202011_PM10=kyungbuk_202011_df["PM10"].mean()
kyungbuk_202011_PM25=kyungbuk_202011_df["PM25"].mean()

kyungbuk_202012_str = json.dumps(kyungbuk_202012_list, default=json_util.default)
kyungbuk_202012 = json.loads(kyungbuk_202012_str)
kyungbuk_202012_df = pd.DataFrame(kyungbuk_202012)
kyungbuk_202012_PM10=kyungbuk_202012_df["PM10"].mean()
kyungbuk_202012_PM25=kyungbuk_202012_df["PM25"].mean()

# %%
kyungnam_202001_str = json.dumps(kyungnam_202001_list, default=json_util.default)
kyungnam_202001 = json.loads(kyungnam_202001_str)
kyungnam_202001_df = pd.DataFrame(kyungnam_202001)
kyungnam_202001_PM10=kyungnam_202001_df["PM10"].mean()
kyungnam_202001_PM25=kyungnam_202001_df["PM25"].mean()

kyungnam_202002_str = json.dumps(kyungnam_202002_list, default=json_util.default)
kyungnam_202002 = json.loads(kyungnam_202002_str)
kyungnam_202002_df = pd.DataFrame(kyungnam_202002)
kyungnam_202002_PM10=kyungnam_202002_df["PM10"].mean()
kyungnam_202002_PM25=kyungnam_202002_df["PM25"].mean()

kyungnam_202003_str = json.dumps(kyungnam_202003_list, default=json_util.default)
kyungnam_202003 = json.loads(kyungnam_202003_str)
kyungnam_202003_df = pd.DataFrame(kyungnam_202003)
kyungnam_202003_PM10=kyungnam_202003_df["PM10"].mean()
kyungnam_202003_PM25=kyungnam_202003_df["PM25"].mean()

kyungnam_202004_str = json.dumps(kyungnam_202004_list, default=json_util.default)
kyungnam_202004 = json.loads(kyungnam_202004_str)
kyungnam_202004_df = pd.DataFrame(kyungnam_202004)
kyungnam_202004_PM10=kyungnam_202004_df["PM10"].mean()
kyungnam_202004_PM25=kyungnam_202004_df["PM25"].mean()

kyungnam_202005_str = json.dumps(kyungnam_202005_list, default=json_util.default)
kyungnam_202005 = json.loads(kyungnam_202005_str)
kyungnam_202005_df = pd.DataFrame(kyungnam_202005)
kyungnam_202005_PM10=kyungnam_202005_df["PM10"].mean()
kyungnam_202005_PM25=kyungnam_202005_df["PM25"].mean()

kyungnam_202006_str = json.dumps(kyungnam_202006_list, default=json_util.default)
kyungnam_202006 = json.loads(kyungnam_202006_str)
kyungnam_202006_df = pd.DataFrame(kyungnam_202006)
kyungnam_202006_PM10=kyungnam_202006_df["PM10"].mean()
kyungnam_202006_PM25=kyungnam_202006_df["PM25"].mean()

kyungnam_202007_str = json.dumps(kyungnam_202007_list, default=json_util.default)
kyungnam_202007 = json.loads(kyungnam_202007_str)
kyungnam_202007_df = pd.DataFrame(kyungnam_202007)
kyungnam_202007_PM10=kyungnam_202007_df["PM10"].mean()
kyungnam_202007_PM25=kyungnam_202007_df["PM25"].mean()

kyungnam_202008_str = json.dumps(kyungnam_202008_list, default=json_util.default)
kyungnam_202008 = json.loads(kyungnam_202008_str)
kyungnam_202008_df = pd.DataFrame(kyungnam_202008)
kyungnam_202008_PM10=kyungnam_202008_df["PM10"].mean()
kyungnam_202008_PM25=kyungnam_202008_df["PM25"].mean()

kyungnam_202009_str = json.dumps(kyungnam_202009_list, default=json_util.default)
kyungnam_202009 = json.loads(kyungnam_202009_str)
kyungnam_202009_df = pd.DataFrame(kyungnam_202009)
kyungnam_202009_PM10=kyungnam_202009_df["PM10"].mean()
kyungnam_202009_PM25=kyungnam_202009_df["PM25"].mean()

kyungnam_202010_str = json.dumps(kyungnam_202010_list, default=json_util.default)
kyungnam_202010 = json.loads(kyungnam_202010_str)
kyungnam_202010_df = pd.DataFrame(kyungnam_202010)
kyungnam_202010_PM10=kyungnam_202010_df["PM10"].mean()
kyungnam_202010_PM25=kyungnam_202010_df["PM25"].mean()

kyungnam_202011_str = json.dumps(kyungnam_202011_list, default=json_util.default)
kyungnam_202011 = json.loads(kyungnam_202011_str)
kyungnam_202011_df = pd.DataFrame(kyungnam_202011)
kyungnam_202011_PM10=kyungnam_202011_df["PM10"].mean()
kyungnam_202011_PM25=kyungnam_202011_df["PM25"].mean()

kyungnam_202012_str = json.dumps(kyungnam_202012_list, default=json_util.default)
kyungnam_202012 = json.loads(kyungnam_202012_str)
kyungnam_202012_df = pd.DataFrame(kyungnam_202012)
kyungnam_202012_PM10=kyungnam_202012_df["PM10"].mean()
kyungnam_202012_PM25=kyungnam_202012_df["PM25"].mean()

# %%
jeju_202001_str = json.dumps(jeju_202001_list, default=json_util.default)
jeju_202001 = json.loads(jeju_202001_str)
jeju_202001_df = pd.DataFrame(jeju_202001)
jeju_202001_PM10=jeju_202001_df["PM10"].mean()
jeju_202001_PM25=jeju_202001_df["PM25"].mean()

jeju_202002_str = json.dumps(jeju_202002_list, default=json_util.default)
jeju_202002 = json.loads(jeju_202002_str)
jeju_202002_df = pd.DataFrame(jeju_202002)
jeju_202002_PM10=jeju_202002_df["PM10"].mean()
jeju_202002_PM25=jeju_202002_df["PM25"].mean()

jeju_202003_str = json.dumps(jeju_202003_list, default=json_util.default)
jeju_202003 = json.loads(jeju_202003_str)
jeju_202003_df = pd.DataFrame(jeju_202003)
jeju_202003_PM10=jeju_202003_df["PM10"].mean()
jeju_202003_PM25=jeju_202003_df["PM25"].mean()

jeju_202004_str = json.dumps(jeju_202004_list, default=json_util.default)
jeju_202004 = json.loads(jeju_202004_str)
jeju_202004_df = pd.DataFrame(jeju_202004)
jeju_202004_PM10=jeju_202004_df["PM10"].mean()
jeju_202004_PM25=jeju_202004_df["PM25"].mean()

jeju_202005_str = json.dumps(jeju_202005_list, default=json_util.default)
jeju_202005 = json.loads(jeju_202005_str)
jeju_202005_df = pd.DataFrame(jeju_202005)
jeju_202005_PM10=jeju_202005_df["PM10"].mean()
jeju_202005_PM25=jeju_202005_df["PM25"].mean()

jeju_202006_str = json.dumps(jeju_202006_list, default=json_util.default)
jeju_202006 = json.loads(jeju_202006_str)
jeju_202006_df = pd.DataFrame(jeju_202006)
jeju_202006_PM10=jeju_202006_df["PM10"].mean()
jeju_202006_PM25=jeju_202006_df["PM25"].mean()

jeju_202007_str = json.dumps(jeju_202007_list, default=json_util.default)
jeju_202007 = json.loads(jeju_202007_str)
jeju_202007_df = pd.DataFrame(jeju_202007)
jeju_202007_PM10=jeju_202007_df["PM10"].mean()
jeju_202007_PM25=jeju_202007_df["PM25"].mean()

jeju_202008_str = json.dumps(jeju_202008_list, default=json_util.default)
jeju_202008 = json.loads(jeju_202008_str)
jeju_202008_df = pd.DataFrame(jeju_202008)
jeju_202008_PM10=jeju_202008_df["PM10"].mean()
jeju_202008_PM25=jeju_202008_df["PM25"].mean()

jeju_202009_str = json.dumps(jeju_202009_list, default=json_util.default)
jeju_202009 = json.loads(jeju_202009_str)
jeju_202009_df = pd.DataFrame(jeju_202009)
jeju_202009_PM10=jeju_202009_df["PM10"].mean()
jeju_202009_PM25=jeju_202009_df["PM25"].mean()

jeju_202010_str = json.dumps(jeju_202010_list, default=json_util.default)
jeju_202010 = json.loads(jeju_202010_str)
jeju_202010_df = pd.DataFrame(jeju_202010)
jeju_202010_PM10=jeju_202010_df["PM10"].mean()
jeju_202010_PM25=jeju_202010_df["PM25"].mean()

jeju_202011_str = json.dumps(jeju_202011_list, default=json_util.default)
jeju_202011 = json.loads(jeju_202011_str)
jeju_202011_df = pd.DataFrame(jeju_202011)
jeju_202011_PM10=jeju_202011_df["PM10"].mean()
jeju_202011_PM25=jeju_202011_df["PM25"].mean()

jeju_202012_str = json.dumps(jeju_202012_list, default=json_util.default)
jeju_202012 = json.loads(jeju_202012_str)
jeju_202012_df = pd.DataFrame(jeju_202012)
jeju_202012_PM10=jeju_202012_df["PM10"].mean()
jeju_202012_PM25=jeju_202012_df["PM25"].mean()

# %%
import numpy as np

# 지도에 그릴 미먼 데이터
sido_nm = np.array(["서울특별시", "부산광역시", "대구광역시", "인천광역시",
             "광주광역시", "대전광역시", "울산광역시", "세종특별자치시",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주특별자치도"])

# 미세먼지 데이터
aqi_202001_PM10 = np.array([seoul_202001_PM10, busan_202001_PM10, daegu_202001_PM10, incheon_202001_PM10,
           gwangju_202001_PM10, daejeon_202001_PM10, ulsan_202001_PM10, sejong_202001_PM10,
           gyeongi_202001_PM10, gangwon_202001_PM10, chungbuk_202001_PM10, chungnam_202001_PM10, jeonbuk_202001_PM10,
           jeonnam_202001_PM10, kyungbuk_202001_PM10, kyungnam_202001_PM10, jeju_202001_PM10])

aqi_202002_PM10 = np.array([seoul_202002_PM10, busan_202002_PM10, daegu_202002_PM10, incheon_202002_PM10,
           gwangju_202002_PM10, daejeon_202002_PM10, ulsan_202002_PM10, sejong_202002_PM10,
           gyeongi_202002_PM10, gangwon_202002_PM10, chungbuk_202002_PM10, chungnam_202002_PM10, jeonbuk_202002_PM10,
           jeonnam_202002_PM10, kyungbuk_202002_PM10, kyungnam_202002_PM10, jeju_202002_PM10])
  
aqi_202003_PM10 = np.array([seoul_202003_PM10, busan_202003_PM10, daegu_202003_PM10, incheon_202003_PM10,
           gwangju_202003_PM10, daejeon_202003_PM10, ulsan_202003_PM10, sejong_202003_PM10,
           gyeongi_202003_PM10, gangwon_202003_PM10, chungbuk_202003_PM10, chungnam_202003_PM10, jeonbuk_202003_PM10,
           jeonnam_202003_PM10, kyungbuk_202003_PM10, kyungnam_202003_PM10, jeju_202003_PM10])

aqi_202004_PM10 = np.array([seoul_202004_PM10, busan_202004_PM10, daegu_202004_PM10, incheon_202004_PM10,
           gwangju_202004_PM10, daejeon_202004_PM10, ulsan_202004_PM10, sejong_202004_PM10,
           gyeongi_202004_PM10, gangwon_202004_PM10, chungbuk_202004_PM10, chungnam_202004_PM10, jeonbuk_202004_PM10,
           jeonnam_202004_PM10, kyungbuk_202004_PM10, kyungnam_202004_PM10, jeju_202004_PM10])

aqi_202005_PM10 = np.array([seoul_202005_PM10, busan_202005_PM10, daegu_202005_PM10, incheon_202005_PM10,
           gwangju_202005_PM10, daejeon_202005_PM10, ulsan_202005_PM10, sejong_202005_PM10,
           gyeongi_202005_PM10, gangwon_202005_PM10, chungbuk_202005_PM10, chungnam_202005_PM10, jeonbuk_202005_PM10,
           jeonnam_202005_PM10, kyungbuk_202005_PM10, kyungnam_202005_PM10, jeju_202005_PM10])

aqi_202006_PM10 = np.array([seoul_202006_PM10, busan_202006_PM10, daegu_202006_PM10, incheon_202006_PM10,
           gwangju_202006_PM10, daejeon_202006_PM10, ulsan_202006_PM10, sejong_202006_PM10,
           gyeongi_202006_PM10, gangwon_202006_PM10, chungbuk_202006_PM10, chungnam_202006_PM10, jeonbuk_202006_PM10,
           jeonnam_202006_PM10, kyungbuk_202006_PM10, kyungnam_202006_PM10, jeju_202006_PM10])  

aqi_202007_PM10 = np.array([seoul_202007_PM10, busan_202007_PM10, daegu_202007_PM10, incheon_202007_PM10,
           gwangju_202007_PM10, daejeon_202007_PM10, ulsan_202007_PM10, sejong_202007_PM10,
           gyeongi_202007_PM10, gangwon_202007_PM10, chungbuk_202007_PM10, chungnam_202007_PM10, jeonbuk_202007_PM10,
           jeonnam_202007_PM10, kyungbuk_202007_PM10, kyungnam_202007_PM10, jeju_202007_PM10])

aqi_202008_PM10 = np.array([seoul_202008_PM10, busan_202008_PM10, daegu_202008_PM10, incheon_202008_PM10,
           gwangju_202008_PM10, daejeon_202008_PM10, ulsan_202008_PM10, sejong_202008_PM10,
           gyeongi_202008_PM10, gangwon_202008_PM10, chungbuk_202008_PM10, chungnam_202008_PM10, jeonbuk_202008_PM10,
           jeonnam_202008_PM10, kyungbuk_202008_PM10, kyungnam_202008_PM10, jeju_202008_PM10]) 

aqi_202009_PM10 = np.array([seoul_202009_PM10, busan_202009_PM10, daegu_202009_PM10, incheon_202009_PM10,
           gwangju_202009_PM10, daejeon_202009_PM10, ulsan_202009_PM10, sejong_202009_PM10,
           gyeongi_202009_PM10, gangwon_202009_PM10, chungbuk_202009_PM10, chungnam_202009_PM10, jeonbuk_202009_PM10,
           jeonnam_202009_PM10, kyungbuk_202009_PM10, kyungnam_202009_PM10, jeju_202009_PM10])

aqi_202010_PM10 = np.array([seoul_202010_PM10, busan_202010_PM10, daegu_202010_PM10, incheon_202010_PM10,
           gwangju_202010_PM10, daejeon_202010_PM10, ulsan_202010_PM10, sejong_202010_PM10,
           gyeongi_202010_PM10, gangwon_202010_PM10, chungbuk_202010_PM10, chungnam_202010_PM10, jeonbuk_202010_PM10,
           jeonnam_202010_PM10, kyungbuk_202010_PM10, kyungnam_202010_PM10, jeju_202010_PM10])
  
aqi_202011_PM10 = np.array([seoul_202011_PM10, busan_202011_PM10, daegu_202011_PM10, incheon_202011_PM10,
           gwangju_202011_PM10, daejeon_202011_PM10, ulsan_202011_PM10, sejong_202011_PM10,
           gyeongi_202011_PM10, gangwon_202011_PM10, chungbuk_202011_PM10, chungnam_202011_PM10, jeonbuk_202011_PM10,
           jeonnam_202011_PM10, kyungbuk_202011_PM10, kyungnam_202011_PM10, jeju_202011_PM10])
 
aqi_202012_PM10 = np.array([seoul_202012_PM10, busan_202012_PM10, daegu_202012_PM10, incheon_202012_PM10,
           gwangju_202012_PM10, daejeon_202012_PM10, ulsan_202012_PM10, sejong_202012_PM10,
           gyeongi_202012_PM10, gangwon_202012_PM10, chungbuk_202012_PM10, chungnam_202012_PM10, jeonbuk_202012_PM10,
           jeonnam_202012_PM10, kyungbuk_202012_PM10, kyungnam_202012_PM10, jeju_202012_PM10])

# 초미세먼지 데이터
aqi_202001_PM25 = np.array([seoul_202001_PM25, busan_202001_PM25, daegu_202001_PM25, incheon_202001_PM25,
           gwangju_202001_PM25, daejeon_202001_PM25, ulsan_202001_PM25, sejong_202001_PM25,
           gyeongi_202001_PM25, gangwon_202001_PM25, chungbuk_202001_PM25, chungnam_202001_PM25, jeonbuk_202001_PM25,
           jeonnam_202001_PM25, kyungbuk_202001_PM25, kyungnam_202001_PM25, jeju_202001_PM25])

aqi_202002_PM25 = np.array([seoul_202002_PM25, busan_202002_PM25, daegu_202002_PM25, incheon_202002_PM25,
           gwangju_202002_PM25, daejeon_202002_PM25, ulsan_202002_PM25, sejong_202002_PM25,
           gyeongi_202002_PM25, gangwon_202002_PM25, chungbuk_202002_PM25, chungnam_202002_PM25, jeonbuk_202002_PM25,
           jeonnam_202002_PM25, kyungbuk_202002_PM25, kyungnam_202002_PM25, jeju_202002_PM25])
  
aqi_202003_PM25 = np.array([seoul_202003_PM25, busan_202003_PM25, daegu_202003_PM25, incheon_202003_PM25,
           gwangju_202003_PM25, daejeon_202003_PM25, ulsan_202003_PM25, sejong_202003_PM25,
           gyeongi_202003_PM25, gangwon_202003_PM25, chungbuk_202003_PM25, chungnam_202003_PM25, jeonbuk_202003_PM25,
           jeonnam_202003_PM25, kyungbuk_202003_PM25, kyungnam_202003_PM25, jeju_202003_PM25])		

aqi_202004_PM25 = np.array([seoul_202004_PM25, busan_202004_PM25, daegu_202004_PM25, incheon_202004_PM25,
           gwangju_202004_PM25, daejeon_202004_PM25, ulsan_202004_PM25, sejong_202004_PM25,
           gyeongi_202004_PM25, gangwon_202004_PM25, chungbuk_202004_PM25, chungnam_202004_PM25, jeonbuk_202004_PM25,
           jeonnam_202004_PM25, kyungbuk_202004_PM25, kyungnam_202004_PM25, jeju_202004_PM25])

aqi_202005_PM25 = np.array([seoul_202005_PM25, busan_202005_PM25, daegu_202005_PM25, incheon_202005_PM25,
           gwangju_202005_PM25, daejeon_202005_PM25, ulsan_202005_PM25, sejong_202005_PM25,
           gyeongi_202005_PM25, gangwon_202005_PM25, chungbuk_202005_PM25, chungnam_202005_PM25, jeonbuk_202005_PM25,
           jeonnam_202005_PM25, kyungbuk_202005_PM25, kyungnam_202005_PM25, jeju_202005_PM25])

aqi_202006_PM25 = np.array([seoul_202006_PM25, busan_202006_PM25, daegu_202006_PM25, incheon_202006_PM25,
           gwangju_202006_PM25, daejeon_202006_PM25, ulsan_202006_PM25, sejong_202006_PM25,
           gyeongi_202006_PM25, gangwon_202006_PM25, chungbuk_202006_PM25, chungnam_202006_PM25, jeonbuk_202006_PM25,
           jeonnam_202006_PM25, kyungbuk_202006_PM25, kyungnam_202006_PM25, jeju_202006_PM25])  

aqi_202007_PM25 = np.array([seoul_202007_PM25, busan_202007_PM25, daegu_202007_PM25, incheon_202007_PM25,
           gwangju_202007_PM25, daejeon_202007_PM25, ulsan_202007_PM25, sejong_202007_PM25,
           gyeongi_202007_PM25, gangwon_202007_PM25, chungbuk_202007_PM25, chungnam_202007_PM25, jeonbuk_202007_PM25,
           jeonnam_202007_PM25, kyungbuk_202007_PM25, kyungnam_202007_PM25, jeju_202007_PM25])
  
aqi_202008_PM25 = np.array([seoul_202008_PM25, busan_202008_PM25, daegu_202008_PM25, incheon_202008_PM25,
           gwangju_202008_PM25, daejeon_202008_PM25, ulsan_202008_PM25, sejong_202008_PM25,
           gyeongi_202008_PM25, gangwon_202008_PM25, chungbuk_202008_PM25, chungnam_202008_PM25, jeonbuk_202008_PM25,
           jeonnam_202008_PM25, kyungbuk_202008_PM25, kyungnam_202008_PM25, jeju_202008_PM25])

aqi_202009_PM25 = np.array([seoul_202009_PM25, busan_202009_PM25, daegu_202009_PM25, incheon_202009_PM25,
           gwangju_202009_PM25, daejeon_202009_PM25, ulsan_202009_PM25, sejong_202009_PM25,
           gyeongi_202009_PM25, gangwon_202009_PM25, chungbuk_202009_PM25, chungnam_202009_PM25, jeonbuk_202009_PM25,
           jeonnam_202009_PM25, kyungbuk_202009_PM25, kyungnam_202009_PM25, jeju_202009_PM25]) 

aqi_202010_PM25 = np.array([seoul_202010_PM25, busan_202010_PM25, daegu_202010_PM25, incheon_202010_PM25,
           gwangju_202010_PM25, daejeon_202010_PM25, ulsan_202010_PM25, sejong_202010_PM25,
           gyeongi_202010_PM25, gangwon_202010_PM25, chungbuk_202010_PM25, chungnam_202010_PM25, jeonbuk_202010_PM25,
           jeonnam_202010_PM25, kyungbuk_202010_PM25, kyungnam_202010_PM25, jeju_202010_PM25])

aqi_202011_PM25 = np.array([seoul_202011_PM25, busan_202011_PM25, daegu_202011_PM25, incheon_202011_PM25,
           gwangju_202011_PM25, daejeon_202011_PM25, ulsan_202011_PM25, sejong_202011_PM25,
           gyeongi_202011_PM25, gangwon_202011_PM25, chungbuk_202011_PM25, chungnam_202011_PM25, jeonbuk_202011_PM25,
           jeonnam_202011_PM25, kyungbuk_202011_PM25, kyungnam_202011_PM25, jeju_202011_PM25])
  
aqi_202012_PM25 = np.array([seoul_202012_PM25, busan_202012_PM25, daegu_202012_PM25, incheon_202012_PM25,
           gwangju_202012_PM25, daejeon_202012_PM25, ulsan_202012_PM25, sejong_202012_PM25,
           gyeongi_202012_PM25, gangwon_202012_PM25, chungbuk_202012_PM25, chungnam_202012_PM25, jeonbuk_202012_PM25,
           jeonnam_202012_PM25, kyungbuk_202012_PM25, kyungnam_202012_PM25, jeju_202012_PM25])

# 미세먼지 DF
aqidata202001_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202001_PM10})
aqidata202002_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202002_PM10})
aqidata202003_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202003_PM10})
aqidata202004_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202004_PM10})
aqidata202005_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202005_PM10})
aqidata202006_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202006_PM10})
aqidata202007_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202007_PM10})
aqidata202008_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202008_PM10})
aqidata202009_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202009_PM10})
aqidata202010_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202010_PM10})
aqidata202011_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202011_PM10})
aqidata202012_PM10 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202012_PM10})


# 초미세먼지 DF
aqidata202001_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202001_PM25})
aqidata202002_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202002_PM25})
aqidata202003_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202003_PM25})
aqidata202004_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202004_PM25})
aqidata202005_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202005_PM25})
aqidata202006_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202006_PM25})
aqidata202007_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202007_PM25})
aqidata202008_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202008_PM25})
aqidata202009_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202009_PM25})
aqidata202010_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202010_PM25})
aqidata202011_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202011_PM25})
aqidata202012_PM25 = pd.DataFrame({"sido_nm":sido_nm, "aqi":aqi_202012_PM25})

# %% [markdown]
# # 시도별 미세,초미세먼지 농도 시각화

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np



x = pd.DataFrame({ "미세먼지":aqi_202001_PM10, "초미세먼지":aqi_202001_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 1월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)



x = pd.DataFrame({ "미세먼지":aqi_202002_PM10, "초미세먼지":aqi_202002_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 2월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202003_PM10, "초미세먼지":aqi_202003_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 3월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202004_PM10, "초미세먼지":aqi_202004_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 4월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202005_PM10, "초미세먼지":aqi_202005_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 5월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202006_PM10, "초미세먼지":aqi_202006_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 6월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202007_PM10, "초미세먼지":aqi_202007_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 7월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202008_PM10, "초미세먼지":aqi_202008_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 8월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202009_PM10, "초미세먼지":aqi_202009_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 9월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202010_PM10, "초미세먼지":aqi_202010_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 10월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202011_PM10, "초미세먼지":aqi_202011_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 11월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

x = pd.DataFrame({ "미세먼지":aqi_202012_PM10, "초미세먼지":aqi_202012_PM25}, index = ["서울", "부산", "대구", "인천","광주", "대전", "울산", "세종",
             "경기도", "강원도", "충청북도", "충청남도", "전라북도",
             "전라남도", "경상북도", "경상남도",
             "제주도"])
plt.rcParams['figure.figsize'] = [17, 5]
x.plot(kind='bar', title='전국 12월 PM10/25')
plt.xticks(rotation=0, fontsize=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.xlabel('지역',size='large')
plt.ylabel('수치',size='large')
plt.grid(True, color='gray', alpha=0.5)

plt.show()
